# %% [markdown]
# <center>
# ## Exploratory Data Analysis  and Prediction of Reason for rejection of quotations and sales orders at the Enterprise
# <center>Author: Mikhail Burinov (@burmish)

# %% [markdown]
# # Getting to know the data
# A sales order is an electronic document that captures and records of the customer´s request for goods or services.
# The sales order contains all pertinent information to process the customer´s request throughout the whole process cycle.
# The Sales component thus automatically suggests data from master records and control tables that previously have been put aside. As a result, possible input errors occurring during sales order processing and entering of redundant data is avoided.
#
# Reason for rejection (Or known as "Rejection reason") is a very commonly used functionality to specify whether a certain line item in the sales order is rejected (Blocked for further processing) or not.
# Our goal is to analyzenthe data and try several hypothesis on prediction of Reason for rejection.
#
# Firstly, we read into DataFrame our dataset for Reason for rejection of quotations and sales orders at the Enterprise:

# %%
from __future__ import division, print_function
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
pd.set_option('display.max.columns', 100)
import pylab as plt
# %matplotlib inline
import seaborn as sns
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (10, 8)

# %%
df = pd.read_csv('rfr.csv',sep=';',thousands=".", decimal=",")
md = pd.read_csv('REASON_REJ.csv',sep=';')

# %% [markdown]
# Let's print the shape of the loaded dataframe and examine the features we are given.

# %%
df.head(15)
# Out:
#     Sales document Partner Function  Item  Item.1  Billing document   R  \
# 0          3411848               SH    10    10.0       163002241.0 NaN
# 1          3411848               SP    10    10.0       163002241.0 NaN
# 2          3411850               SH    10    10.0       163002227.0 NaN
# 3          3411850               SP    10    10.0       163002227.0 NaN
# 4          3411851               SH    10    10.0       163002240.0 NaN
# 5          3411851               SP    10    10.0       163002240.0 NaN
# 6          3412466               SH    10    10.0       162001604.0 NaN
# 7          3412466               SH    10    10.0       163001643.0 NaN
# 8          3412466               SP    10    10.0       162001604.0 NaN
# 9          3412466               SP    10    10.0       163001643.0 NaN
# 10         3412468               SH    10    10.0       163000762.0 NaN
# 11         3412468               SP    10    10.0       163000762.0 NaN
# 12         3412499               SH    10    10.0       163000869.0 NaN
# 13         3412499               SP    10    10.0       163000869.0 NaN
# 14         3412589               SH    10    10.0       162001524.0 NaN
#
#     Reason for rejection  Reason for order Condition Incoterms  Created on  \
# 0                    NaN               NaN        M3       DAP  01/02/2015
# 1                    NaN               NaN        M3       DAP  01/02/2015
# 2                    NaN               NaN        M3       DAP  01/02/2015
# 3                    NaN               NaN        M3       DAP  01/02/2015
# 4                    NaN               NaN        M3       DAP  01/02/2015
# 5                    NaN               NaN        M3       DAP  01/02/2015
# 6                    NaN               NaN       PAK       FCA  01/05/2015
# 7                    NaN               NaN       PAK       FCA  01/05/2015
# 8                    NaN               NaN       PAK       FCA  01/05/2015
# 9                    NaN               NaN       PAK       FCA  01/05/2015
# 10                   NaN               NaN        ST       DAP  01/05/2015
# 11                   NaN               NaN        ST       DAP  01/05/2015
# 12                   NaN               NaN        ST       DAP  01/05/2015
# 13                   NaN               NaN        ST       DAP  01/05/2015
# 14                   NaN               NaN        ST       DAP  01/05/2015
#
#     Actual Invoiced Quan  Bill.quan.stock unit Base Unit Sales unit  \
# 0                  140.0                 140.0        M3         M3
# 1                  140.0                 140.0        M3         M3
# 2                  120.0                 120.0        M3         M3
# 3                  120.0                 120.0        M3         M3
# 4                  280.0                 280.0        M3         M3
# 5                  280.0                 280.0        M3         M3
# 6                 4824.0                 402.0       PAK         ST
# 7                 4824.0                 402.0       PAK         ST
# 8                 4824.0                 402.0       PAK         ST
# 9                 4824.0                 402.0       PAK         ST
# 10                   1.0                   1.0        ST         ST
# 11                   1.0                   1.0        ST         ST
# 12               79040.0                  20.0       PAL         ST
# 13               79040.0                  20.0       PAL         ST
# 14                1280.0                  10.0       PAL         ST
#
#    Document c  Net priceSO  Net valueSO  Condition pric. unit  \
# 0         EUR        23.90      3346.00                     1
# 1         EUR        23.90      3346.00                     1
# 2         EUR        23.90      2868.00                     1
# 3         EUR        23.90      2868.00                     1
# 4         EUR        23.90      6692.00                     1
# 5         EUR        23.90      6692.00                     1
# 6         EUR        10.80      4341.60                     1
# 7         EUR        10.80      4341.60                     1
# 8         EUR        10.80      4341.60                     1
# 9         EUR        10.80      4341.60                     1
# 10        EUR      6750.00      6750.00                     1
# 11        EUR      6750.00      6750.00                     1
# 12        EUR        70.30      5556.51                  1000
# 13        EUR        70.30      5556.51                  1000
# 14        PLN         4.04      5171.20                     1
#
#     CumConfirmedQty Base Unit.1 Invoice created Invoice created by  \
# 0               140          M3      15/01/2015         SYS-BTC-FI
# 1               140          M3      15/01/2015         SYS-BTC-FI
# 2               120          M3      15/01/2015         SYS-BTC-FI
# 3               120          M3      15/01/2015         SYS-BTC-FI
# 4               280          M3      15/01/2015         SYS-BTC-FI
# 5               280          M3      15/01/2015         SYS-BTC-FI
# 6               402         PAK      13/01/2015              ARKAR
# 7               402         PAK      13/01/2015              ARKAR
# 8               402         PAK      13/01/2015              ARKAR
# 9               402         PAK      13/01/2015              ARKAR
# 10                1          ST      01/08/2015         SYS-BTC-FI
# 11                1          ST      01/08/2015         SYS-BTC-FI
# 12               20         PAL      01/08/2015         SYS-BTC-FI
# 13               20         PAL      01/08/2015         SYS-BTC-FI
# 14               10         PAL      13/01/2015              MASZA
#
#    Billing doc/ date  Billing status Payment condition Order unit  \
# 0         15/01/2015             NaN              I108         M3
# 1         15/01/2015             NaN              I108         M3
# 2         15/01/2015             NaN              I011         M3
# 3         15/01/2015             NaN              I011         M3
# 4         15/01/2015             NaN              I011         M3
# 5         15/01/2015             NaN              I011         M3
# 6         13/01/2015             NaN              N014         ST
# 7         13/01/2015             NaN              N014         ST
# 8         13/01/2015             NaN              N014         ST
# 9         13/01/2015             NaN              N014         ST
# 10        01/08/2015             NaN              I108         ST
# 11        01/08/2015             NaN              I108         ST
# 12        01/08/2015             NaN              H260         ST
# 13        01/08/2015             NaN              H260         ST
# 14        13/01/2015             NaN              NM50         ST
#
#    Document c.1  Net valueB  Confirmed qty.  Material  Customer  Division  \
# 0           EUR     3346.00             140    134409     22983        99
# 1           EUR     3346.00             140    134409     22983        99
# 2           EUR     2868.00             120    134409     22290        99
# 3           EUR     2868.00             120    134409     22290        99
# 4           EUR     6692.00             280    134409     22938        99
# 5           EUR     6692.00             280    134409     22938        99
# 6           PLN    12606.72            4824     52599     28984        99
# 7           EUR     4341.60            4824     52599     28984        99
# 8           PLN    12606.72            4824     52599     28984        99
# 9           EUR     4341.60            4824     52599     28984        99
# 10          EUR     6750.00               1    132243     22398        99
# 11          EUR     6750.00               1    132243     23775        99
# 12          EUR     5556.51           79040     69375     22366        99
# 13          EUR     5556.51           79040     69375     22366        99
# 14          PLN     3099.89            1280    117822     56377        99
#
#    Sales Organization Shipping conditions  Distribution Channel Plant  \
# 0                NL05                  70                     1  NL01
# 1                NL05                  70                     1  NL01
# 2                NL05                  70                     1  NL01
# 3                NL05                  70                     1  NL01
# 4                NL05                  70                     1  NL01
# 5                NL05                  70                     1  NL01
# 6                NL05                   2                     1  PL13
# 7                NL05                   2                     1  PL13
# 8                NL05                   2                     1  PL13
# 9                NL05                   2                     1  PL13
# 10               NL05                   6                     1  NL01
# 11               NL05                   6                     1  NL01
# 12               NL05                  70                     1  NL02
# 13               NL05                  70                     1  NL02
# 14               NL05                  B5                     1  PL02
#
#     Sold-to party Schedule line date Billing type Sales doc. type
# 0           22983         01/07/2015          ZF4            ZOR1
# 1           22983         01/07/2015          ZF4            ZOR1
# 2           22290         01/07/2015          ZF4            ZOR1
# 3           22290         01/07/2015          ZF4            ZOR1
# 4           22938         01/07/2015          ZF4            ZOR1
# 5           22938         01/07/2015          ZF4            ZOR1
# 6           28984         14/01/2015          ZIV             ZOR
# 7           28984         14/01/2015          ZF2             ZOR
# 8           28984         14/01/2015          ZIV             ZOR
# 9           28984         14/01/2015          ZF2             ZOR
# 10          23775         01/09/2015          ZF4            ZOR1
# 11          23775         01/09/2015          ZF4            ZOR1
# 12          22366         01/08/2015          ZF2             ZOR
# 13          22366         01/08/2015          ZF2             ZOR
# 14          30966         13/01/2015          ZIV             ZOR

# %% [markdown]
# Let's have a look at the features and make sure that we don't have missing rows.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 41 columns):
# Sales document          29999 non-null int64
# Partner Function        29999 non-null object
# Item                    29999 non-null int64
# Item.1                  25675 non-null float64
# Billing document        25675 non-null float64
# R                       0 non-null float64
# Reason for rejection    11290 non-null float64
# Reason for order        340 non-null float64
# Condition               29999 non-null object
# Incoterms               29999 non-null object
# Created on              29999 non-null object
# Actual Invoiced Quan    25675 non-null float64
# Bill.quan.stock unit    25675 non-null float64
# Base Unit               25675 non-null object
# Sales unit              25675 non-null object
# Document c              29999 non-null object
# Net priceSO             29999 non-null float64
# Net valueSO             29999 non-null float64
# Condition pric. unit    29999 non-null int64
# CumConfirmedQty         29999 non-null int64
# Base Unit.1             29999 non-null object
# Invoice created         25675 non-null object
# Invoice created by      25675 non-null object
# Billing doc/ date       25675 non-null object
# Billing status          0 non-null float64
# Payment condition       29999 non-null object
# Order unit              29999 non-null object
# Document c.1            29999 non-null object
# Net valueB              29999 non-null float64
# Confirmed qty.          29999 non-null int64
# Material                29999 non-null int64
# Customer                29999 non-null int64
# Division                29999 non-null int64
# Sales Organization      29999 non-null object
# Shipping conditions     29999 non-null object
# Distribution Channel    29999 non-null int64
# Plant                   29999 non-null object
# Sold-to party           29999 non-null int64
# Schedule line date      29999 non-null object
# Billing type            25675 non-null object
# Sales doc. type         29999 non-null object
# dtypes: float64(11), int64(10), object(20)
# memory usage: 9.4+ MB

# %% [markdown]
# We notice 3 empty features: "R", "Reason for order ", "Billing status". Let's get rid of them.
#
# Let's also work with date format in the dataset:

# %%
df=df.drop( ['R', 'Reason for order', 'Billing status'], axis=1)
df.drop_duplicates(inplace = True)

# %%
df['Created on'] = pd.to_datetime(df['Created on'],format="%d/%m/%Y")
df['Invoice created'] = pd.to_datetime(df['Invoice created'],format="%d/%m/%Y")
df['Billing doc/ date'] = pd.to_datetime(df['Billing doc/ date'],format="%d/%m/%Y")
df['Schedule line date'] = pd.to_datetime(df['Schedule line date'],format="%d/%m/%Y")

# %% [markdown]
# Now let's look at the target feature distribution - Reason for rejection of quotations and sales orders

# %% [markdown]
# Features description
#
# |  Name  | Description | Type |
# |---         |--:       |     |
# | **Sales Document** | id of Sales order | categorical |
# | **Partner Function** | Partner function allows you to identify which functions a partner has to perform in any business process| categorica |
# | **Item ** |Item number inside Sales order | categorical  |
# | **Item.1  ** | Item number for billing document |categorical |
# | **Billing document  ** | id of Billing document | categorical |
# | **Incoterms ** | internationally-recognized terms of delivery reflecting the standards set by the International Chamber of Commerce (ICC) | categorical|
# | **Created on** | Date on which the record was created |numeric  |
# | **Actual Invoiced Quan ** | Actual Invoiced Quantity of the product | numeric |
# | **Bill.quan.stock unit** | Billing quantity in stockkeeping unit | numeric |
# | **Base Unit  ** | Base Units of measurements | categorical |
# | **Sales unit ** | Sales units of mesurements | categorical |
# | **Document c    ** | Currency | categorical |
# | **Net priceSO ** | Net price | numeric |
# | **Net valueSO ** | Net value of the order item in document currency | numeric |
# | **Condition pric. unit** | Condition pricing unit |  categorical |
# | **CumConfirmedQty** | Cumulative confirmed quantity in base unit | numeric |
# | **Base Unit.1** |Cumulative quantity Unit |  categorical |
# | **Invoice created** | Invoice creation date |  numeric|
# | **Invoice created by ** | User name who created invoice | categorical |
# | **Billing doc. date** | Date of creation of Billing Documnt | numeric |
# | **Payment condition  ** | Payment condition |  categorical |
# | **Order unit ** | Order unit |  categorical |
# | **Document c.1 ** | Document currency for net value |  categorical|
# | **Net valueB ** |Net Value of Billing Item in Document Currency | numeric |
# | **Confirmed qty** | Confirmed quantity | numeric|
# | **Material ** | id of material|  categorical |
# | **Customer** | id of customer |  categorical|
# | **Division** | Division |  categorical |
# | **Sales Organization ** | Sales organization | categorical |
# | **Shipping conditions** | Shipping conditions|  categorical|
# | **Distribution Channel** | Distribution Channel |  categorical |
# | **Plant ** | Plant|  categorical |
# | **Sold-to party** | the customer who is going to place the order to the business |  categorical |
# | **Schedule line date ** | Schedule line date |  categorical|
# | **Billing type** | Billing type|  categorical |
# | **Sales doc. type ** | Sales doc. type |  categorical|
#
# Our target feature: **Reason for rejection** – categorical feature. Later we will build the model that will predict the values of this feature.

# %% [markdown]
# Let's explore our target feature

# %%
df['Reason for rejection'].value_counts()
# Out:
# 52.0    3382
# 11.0    2274
# 4.0     2101
# 14.0    1920
# 12.0     294
# 0.0      240
# 10.0      78
# 30.0      76
# 15.0      66
# 1.0       50
# 2.0       40
# 3.0       22
# 13.0      18
# 5.0        4
# Name: Reason for rejection, dtype: int64

# %% [markdown]
# We also have a master data text for Reason for rejection code. Here wecan see that Reason for rejection'55' stands for 'non conform delivery' or '14' means 'Customer decision'

# %%
md
# Out:
#    Reason for rejection  L                      Medium Description
# 0                     0  E       Assigned by the System (Internal)
# 1                     1  E                  Delivery date too late
# 2                     2  E                            Poor quality
# 3                     3  E                           Too expensive
# 4                     4  E                       Competitor better
# 5                     5  E                               Guarantee
# 6                    10  E                    Unreasonable request
# 7                    11  E             Cust.to receive replacement
# 8                    12  E                          Sales decision
# 9                    13  E                      Financial decision
# 10                   14  E                       Customer decision
# 11                   15  E                        Lack of capacity
# 12                   20  E              Correction to zero - RW-PL
# 13                   30  E              Customer Service - mistake
# 14                   50  E            Transaction is being checked
# 15                   51  E                               Telesales
# 16                   52  E                    non conform delivery
# 17                   55  E                         Re-Open for RRB
# 18                   X0  E  Internet sales: Customer rejected item

# %% [markdown]
# Let's visualize the distribution of Reason for rejection of quotations and sales orders

# %%
df['Reason for rejection'].value_counts().plot(kind='bar', label='rfr')
plt.legend()
plt.title('Reason for rejection');

# %% [markdown]
# For our business purposes it's crucial to predict weather the Sales order was rejected or not. So we will replace value for Reason for rejection from 0 to 52 to 1, and all NaNs will be equal to zero.

# %%
df.loc[df['Reason for rejection'] >= 0, 'Reason for rejection'] = 1
df['Reason for rejection'].fillna(0, inplace = True)
df = df.dropna()

# %%
df['Reason for rejection'].mean()
# Out:
# 0.2535806902054658

# %% [markdown]
# Our dataset is non-balanced by classes in target feature (25%/ 75%).

# %%
df.describe().T
# Out:
#                         count          mean           std         min  \
# Sales document        25065.0  4.454552e+06  6.516347e+06   3411848.0
# Item                  25065.0  2.320032e+01  2.545848e+01        10.0
# Item.1                25065.0  2.423970e+01  2.646677e+01         1.0
# Billing document      25065.0  1.508105e+08  2.490605e+07  95418210.0
# Reason for rejection  25065.0  2.535807e-01  4.350690e-01         0.0
# Actual Invoiced Quan  25065.0  4.348794e+04  1.849609e+05  -5460000.0
# Bill.quan.stock unit  25065.0  3.965445e+02  1.865152e+03    -26960.0
# Net priceSO           25065.0  2.587879e+04  2.131362e+05         0.0
# Net valueSO           25065.0  4.156994e+04  1.799794e+05         0.0
# Condition pric. unit  25065.0  2.300466e+02  9.451040e+02         1.0
# CumConfirmedQty       25065.0  1.097949e+03  1.029095e+04         0.0
# Net valueB            25065.0  2.383374e+04  1.373541e+05  -1747306.0
# Confirmed qty.        25065.0  4.831698e+04  1.852460e+05         0.0
# Material              25065.0  2.125858e+07  9.900531e+07     10701.0
# Customer              25065.0  3.789273e+04  2.000816e+04     17253.0
# Division              25065.0  9.900000e+01  0.000000e+00        99.0
# Distribution Channel  25065.0  1.000000e+00  0.000000e+00         1.0
# Sold-to party         25065.0  3.421047e+04  1.689010e+04     17253.0
#
#                                25%           50%           75%          max
# Sales document        3.504577e+06  3.645382e+06  3.727129e+06   70080645.0
# Item                  1.000000e+01  1.000000e+01  3.000000e+01        280.0
# Item.1                1.000000e+01  1.200000e+01  3.000000e+01        280.0
# Billing document      1.620201e+08  1.630151e+08  1.630346e+08  163372948.0
# Reason for rejection  0.000000e+00  0.000000e+00  1.000000e+00          1.0
# Actual Invoiced Quan  1.680000e+03  5.440000e+03  2.244000e+04    5460000.0
# Bill.quan.stock unit  1.000000e+01  4.000000e+01  1.990000e+02      53856.0
# Net priceSO           4.090000e+00  4.370000e+01  1.432000e+02    4876630.0
# Net valueSO           1.704000e+03  5.366400e+03  1.224288e+04    2398219.0
# Condition pric. unit  1.000000e+00  1.000000e+00  1.000000e+02      10000.0
# CumConfirmedQty       1.000000e+01  5.200000e+01  2.270000e+02     321440.0
# Net valueB            1.169280e+03  4.499040e+03  8.994640e+03    2337031.0
# Confirmed qty.        1.836000e+03  6.528000e+03  3.110400e+04    5880000.0
# Material              5.541500e+04  8.943400e+04  1.322630e+05  500000804.0
# Customer              2.316200e+04  2.772200e+04  4.583900e+04      95179.0
# Division              9.900000e+01  9.900000e+01  9.900000e+01         99.0
# Distribution Channel  1.000000e+00  1.000000e+00  1.000000e+00          1.0
# Sold-to party         2.349100e+04  2.723600e+04  3.935200e+04      95179.0

# %% [markdown]
# From the describe table above we can see that feature 'Distribution channel','Division','Sales Organization' has the constant values.
# I assume that the dataset was created for one distribution chanel, Division of Sales Organizatoin of the enterprise. This will not be helpful for  our classifier. Let's get rid of this features.

# %%
df=df.drop( ['Distribution Channel','Sales Organization','Division'], axis=1)

# %% [markdown]
# Let's explore the number of unique values by features  in the dataset

# %%
feats_counts =df.nunique(dropna = False)
feats_counts.sort_values()
# Out:
# Partner Function           2
# Reason for rejection       2
# Document c.1               7
# Document c                 7
# Sales unit                 7
# Plant                      7
# Incoterms                  7
# Sales doc. type            8
# Base Unit                  9
# Condition                  9
# Base Unit.1                9
# Order unit                10
# Condition pric. unit      12
# Billing type              16
# Shipping conditions       21
# Item                      35
# Invoice created by        71
# Payment condition         75
# Item.1                   142
# CumConfirmedQty          539
# Created on               547
# Sold-to party            594
# Schedule line date       654
# Invoice created          674
# Billing doc/ date        716
# Bill.quan.stock unit     868
# Material                1258
# Customer                1322
# Confirmed qty.          1580
# Actual Invoiced Quan    1990
# Net priceSO             2149
# Sales document          3899
# Net valueSO             4444
# Billing document        7552
# Net valueB              7891
# dtype: int64

# %% [markdown]
# We can see that there is no feature with only 1 unique value.
#
# Let' see the correlation of numeric features

# %% [markdown]
# # Working with dates
# We have several date features in our dataframe.
# The most important feature is 'Created on', which represents date when Sales order has been created.
# We will generate several new categorical and numerical features:
# * Weekday -  weekday when Sales order has been created
# * Month - month when Sales order has been created
# * Week - week when Sales order has been created
# * Year - Year when Sales order has been created
# * Day - Day when Sales order has been created
# * Inv_since_creation - difference between Invoice created dates and Created on date
# * Bill_since_creation - difference between Billind doc/date and Created on date
# * Sched_since_creation - difference between Sched line date and Created on date

# %%
df['Month'] = pd.DatetimeIndex(df['Created on']).month
df['Weekday'] = pd.DatetimeIndex(df['Created on']).weekday
df['Week'] = pd.DatetimeIndex(df['Created on']).week
df['Year'] = pd.DatetimeIndex(df['Created on']).year
df['Day'] = pd.DatetimeIndex(df['Created on']).day
df['Inv_since_creation'] = (df['Invoice created'] - df['Created on']).dt.days
df['Bill_since_creation'] = (df['Billing doc/ date'] - df['Created on']).dt.days
df['Sched_since_creation'] = (df['Schedule line date'] - df['Created on']).dt.days

# %%
corr_matrix = df[['Inv_since_creation', 'Bill_since_creation','Sched_since_creation','Net valueSO','Net priceSO','Actual Invoiced Quan', 'Bill.quan.stock unit','CumConfirmedQty','Invoice created','Net valueB','Reason for rejection']].corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f");

# %% [markdown]
# Now let's look at the distribution of all numeric features.Note that we use logarithmic scale everywhere

# %%
sns.set(style = 'whitegrid', font_scale=1.5)
num_features = list( set(['Inv_since_creation', 'Bill_since_creation','Sched_since_creation','Net valueSO','Net priceSO','Actual Invoiced Quan', 'Bill.quan.stock unit','CumConfirmedQty','Net valueB']))


df[num_features].hist(bins=np.logspace(0.1, 1.0, 50))
plt.gca().set_xscale("log")
plt.show()

# %% [markdown]
# Let's show boxplots, describing key values of disrtibution of numeric features for 2 groups: rejected and non-rejected quotations and sales orders

# %%
sns.set(style = 'whitegrid', font_scale=1.5)
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(13, 15))

for idx, feat in  enumerate(num_features):
    sns.boxplot(x='Reason for rejection', y=feat, data=df, ax=axes[int(idx / 3), idx % 3])
    axes[int(idx / 3), idx % 3].legend()
    axes[int(idx / 3), idx % 3].set_xlabel('Reason for rejection')
    axes[int(idx / 3), idx % 3].set_yscale('log')
    axes[int(idx / 3), idx % 3].set_ylabel(feat);

# %% [markdown]
# We can see the maximal difference is for features Net value B and Actual Invoice Quan. Leter on we will determine the importance of features for classifier with RandomForest algorithm or Gradient Boosting. We will see that these feautres are really important for our prediction
# From the picture we can notice that in general rejected sales orders and quotations has more inovoiced quatnity then non-rejected ones. Maybe there is a connection between quantity of the order and rejection.

# %% [markdown]
# Finally, let's see how categorical feature Document Currency is related to Reason for rejection. We can print a pivot table or count percentage of reason for rejection for every currency of the Sales order.

# %%
pd.crosstab(df['Document c'], df['Reason for rejection']).T
# Out:
# Document c            DKK    EUR  GBP  JPY  NOK   PLN  USD
# Reason for rejection
# 0.0                   354  15475  188  864  318  1438   72
# 1.0                    16   5652   24  454    2   184   24

# %%
df.groupby(['Document c'])['Reason for rejection'].agg([np.mean]).sort_values(by='mean', ascending=False).T
# Out:
# Document c       JPY       EUR   USD      PLN       GBP       DKK      NOK
# mean        0.344461  0.267525  0.25  0.11344  0.113208  0.043243  0.00625

# %% [markdown]
# We can see that for JPY the percentage of rejected order has the highest value - 13%. For Danish Kronas (DKK) there is the lowest value 0.5%. Maybe this happpens because of data quality we have ( we would need to check the hypotesis about Matthews and Cramers correlation)
# # Data preprocessing
# We already done the basic data preprocessing: NaN fitting, deleted redundant features etc.
# Now we will change categorical features with dummy coding and we will scale a numeric features.
#
# So, let's split our data to train, test and validation parts.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from scipy.sparse import hstack
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn import preprocessing
y = df['Reason for rejection']
df = df.drop(['Reason for rejection'], axis=1)
cat_features = list(df.drop(df[num_features], axis = 1).columns.values)
enc = preprocessing.LabelEncoder()
for column in cat_features:
    df[column] = enc.fit_transform(df[column])
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2, shuffle=True,random_state=777)
X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size=0.5, shuffle=True,random_state=777)

# %%
data_scale_train = X_train[num_features]
data_scale_test = X_test[num_features]
scaler = StandardScaler()
data_scaled_train = scaler.fit_transform(data_scale_train)
data_scaled_test = scaler.transform(data_scale_test)

data_dum_train = X_train.drop(X_train[num_features], axis = 1)
data_dum_test = X_test.drop(X_test[num_features], axis = 1)

ohe = OneHotEncoder()
data_ohe_train = ohe.fit_transform(data_dum_train)
data_ohe_test = ohe.transform(data_dum_test)

# %% [markdown]
# # Choosing metrics
# Let's move on to choosing metric of the model.
#
# We have a binary classification task . Let's list all the metrics of quality:
# * Accuracy
# * Recall
# * Precision
# * F1-score
# * Logloss
# * Roc auc
#
# First 3 metrics are quite simple and understandable, but they have many pitfalls. Logloss is ofetn used for optimization task .  Choosing f1-score and roc auc for model evaluation is quite good idea because if both metrics are high, it means that the chosen model is not bad and data is consistent. If one of the metrics is high, and the other one is low, it means that we should find mistakes in our model
# # Choosing a model
# There are several machine learning models for binary classification task:
#
# * KNeighborsClassifier()
# * DecisionTreeClassifier()
# * LinearSVC()
# * LogisticRegression()
# * RandomForestClassifier(),
# * GradientBoostingClassifier()
# * CatBoostClassifier()
#
# We are going to try all of them on basic parameters, then we will chose one and work with it
# # Cross validation and hyperparameters tuning

# %%
X_train_sparse = hstack([data_scaled_train, data_ohe_train\
                                    ]).tocsr(copy = False) 

X_test_sparse = hstack([data_scaled_test, data_ohe_test\
                             ]).tocsr(copy = False)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

from time import time

models = [
    KNeighborsClassifier(),
    DecisionTreeClassifier(random_state = 777),
    LinearSVC(random_state = 777),
    RandomForestClassifier(n_estimators=100, random_state = 777), 
    GradientBoostingClassifier(n_estimators=100, random_state = 777),
    LogisticRegression(random_state = 777),
]

for model in models:
    start = time()
    model.fit(X_train_sparse, y_train)
    score = np.mean(cross_val_score(model, X_train_sparse, y_train, cv=9, scoring='roc_auc'))
    scoref1 = np.mean(cross_val_score(model, X_train_sparse, y_train, cv=9, scoring='f1'))
    end = time()
    ste = end - start
    print('roc auc:', score, '\n', 'f1:', scoref1, '\n', 'time:', ste, '\n', model)
# Out:
# roc auc: 0.992629537306
#  f1: 0.931356436731
#  time: 65.63117694854736
#  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')
# roc auc: 0.994824192174
#  f1: 0.993140374323
#  time: 32.838783979415894
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=777,
#             splitter='best')
# roc auc: 0.999454461654
#  f1: 0.996765998862
#  time: 14.985779047012329
#  LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=777, tol=0.0001,
#      verbose=0)
# roc auc: 0.9997372877
#  f1: 0.992706048227
#  time: 295.1704361438751
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=777, verbose=0, warm_start=False)
# roc auc: 0.979571706728
#  f1: 0.877854744086
#  time: 454.18411588668823
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=777, subsample=1.0, verbose=0,
#               warm_start=False)
# roc auc: 0.99916555014
#  f1: 0.984924841811
#  time: 8.17085599899292
#  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=777, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# From the results above we can see that it is worth to work with DecisionTreeClassifier, LinearSVC, RandomForestClassifier, Logistic Regression because they got best scores on these data

# %% [markdown]
# # Creation of new Polynomial features
# Let's add new features. In general we have many categorical features and several numeric ones. That's why we will add cross-interaction features. We will make 2nd level features, with no polinomial features and with no bias

# %%
poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
data_poly_train = poly.fit_transform(data_dum_train)
data_poly_test = poly.transform(data_dum_test)
#make a DF
data_poly_train = pd.DataFrame(data_poly_train)
data_poly_test = pd.DataFrame(data_poly_test)

scaler = StandardScaler()
data_poly_scaled_train = scaler.fit_transform(data_poly_train)
data_poly_scaled_test = scaler.transform(data_poly_test)

# %%
X_train_sparse = hstack([data_scaled_train, data_ohe_train,\
                                    data_poly_scaled_train]).tocsr(copy = False) 

X_test_sparse = hstack([data_scaled_test, data_ohe_test,\
                             data_poly_scaled_test]).tocsr(copy = False)

# %%
models = [
    DecisionTreeClassifier(random_state = 777),
    LinearSVC(random_state = 777),
    LogisticRegression(random_state = 777)
]

for model in models:
    start = time()
    model.fit(X_train_sparse, y_train)
    score = np.mean(cross_val_score(model, X_train_sparse, y_train, cv=9, scoring='roc_auc'))
    scoref1 = np.mean(cross_val_score(model, X_train_sparse, y_train, cv=9, scoring='f1'))
    end = time()
    ste = end - start
    print('roc auc:', score, '\n', 'f1:', scoref1, '\n', 'time:', ste, '\n', model)
# Out:
# roc auc: 0.996518856166
#  f1: 0.994715015292
#  time: 411.4451150894165
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=777,
#             splitter='best')
# roc auc: 0.999446479446
#  f1: 0.995499218424
#  time: 121.5939428806305
#  LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=777, tol=0.0001,
#      verbose=0)
# roc auc: 0.999203171716
#  f1: 0.984857693691
#  time: 232.23458695411682
#  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=777, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# From the results above we can see that the quality becomes slightly better (extremely good), but the time for model training increased drammaticaly.
# The best score and time shows Logistic regression() model. Therefore, we choose this one.

# %% [markdown]
# # Hyperparameters tuning

# %%
X_train_sparse = hstack([data_scaled_train, data_ohe_train]).tocsr(copy = False)

X_test_sparse = hstack([data_scaled_test, data_ohe_test]).tocsr(copy = False)

# %%
for i in ['liblinear', 'sag', 'saga']:
    for j in [100, 1000, 5000, 10000]:
        for k in [0.1, 1]:
                start = time()
                model = LogisticRegression(solver=i, max_iter=j, C=k, random_state=777)
                model.fit(X_train_sparse, y_train)
                score = np.mean(cross_val_score(model, X_train_sparse, y_train, cv=9, scoring='roc_auc'))
                scoref1 = np.mean(cross_val_score(model, X_train_sparse, y_train, cv=9, scoring='f1'))
                end = time()
                ste = end - start
                print('solver:', i, '\n', 'max_iter:', j, '\n', 'C:', k, '\n',\
                      'roc auc:', score, '\n', 'f1:', scoref1, '\n', 'time:', ste)
# Out:
# solver: liblinear
#  max_iter: 100
#  C: 0.1
#  roc auc: 0.995066994991
#  f1: 0.936281478371
#  time: 5.805028915405273
# solver: liblinear
#  max_iter: 100
#  C: 1
#  roc auc: 0.99916555014
#  f1: 0.984924841811
#  time: 8.12122392654419
# solver: liblinear
#  max_iter: 1000
#  C: 0.1
#  roc auc: 0.995066994991
#  f1: 0.936281478371
#  time: 5.717322826385498
# solver: liblinear
#  max_iter: 1000
#  C: 1
#  roc auc: 0.99916555014
#  f1: 0.984924841811
#  time: 8.158780097961426
# solver: liblinear
#  max_iter: 5000
#  C: 0.1
#  roc auc: 0.995066994991
#  f1: 0.936281478371
#  time: 5.71414589881897
# solver: liblinear
#  max_iter: 5000
#  C: 1
#  roc auc: 0.99916555014
#  f1: 0.984924841811
#  time: 8.171525955200195
# solver: liblinear
#  max_iter: 10000
#  C: 0.1
#  roc auc: 0.995066994991
#  f1: 0.936281478371
#  time: 5.71077299118042
# solver: liblinear
#  max_iter: 10000
#  C: 1
#  roc auc: 0.99916555014
#  f1: 0.984924841811
#  time: 8.154314041137695
# solver: sag
#  max_iter: 100
#  C: 0.1
#  roc auc: 0.99502514148
#  f1: 0.935840016424
#  time: 25.20537805557251
# solver: sag
#  max_iter: 100
#  C: 1
#  roc auc: 0.998533993903
#  f1: 0.972458938483
#  time: 29.37886381149292
# solver: sag
#  max_iter: 1000
#  C: 0.1
#  roc auc: 0.99502514148
#  f1: 0.935840016424
#  time: 27.651842832565308
# solver: sag
#  max_iter: 1000
#  C: 1
#  roc auc: 0.999148214841
#  f1: 0.984619700415
#  time: 127.43985486030579
# solver: sag
#  max_iter: 5000
#  C: 0.1
#  roc auc: 0.99502514148
#  f1: 0.935840016424
#  time: 24.990494966506958
# solver: sag
#  max_iter: 5000
#  C: 1
#  roc auc: 0.999148214841
#  f1: 0.984619700415
#  time: 125.55843997001648
# solver: sag
#  max_iter: 10000
#  C: 0.1
#  roc auc: 0.99502514148
#  f1: 0.935840016424
#  time: 25.58048915863037
# solver: sag
#  max_iter: 10000
#  C: 1
#  roc auc: 0.999148214841
#  f1: 0.984619700415
#  time: 130.0726010799408
# solver: saga
#  max_iter: 100
#  C: 0.1
#  roc auc: 0.994647659054
#  f1: 0.934957871296
#  time: 29.291670083999634
# solver: saga
#  max_iter: 100
#  C: 1
#  roc auc: 0.997382280618
#  f1: 0.959460443297
#  time: 29.03429365158081
# solver: saga
#  max_iter: 1000
#  C: 0.1
#  roc auc: 0.994963838343
#  f1: 0.935840016424
#  time: 45.270358085632324
# solver: saga
#  max_iter: 1000
#  C: 1
#  roc auc: 0.999128763461
#  f1: 0.983827394049
#  time: 212.686527967453
# solver: saga
#  max_iter: 5000
#  C: 0.1
#  roc auc: 0.994963838343
#  f1: 0.935840016424
#  time: 46.32514715194702
# solver: saga
#  max_iter: 5000
#  C: 1
#  roc auc: 0.999128763461
#  f1: 0.983827394049
#  time: 210.77875208854675
# solver: saga
#  max_iter: 10000
#  C: 0.1
#  roc auc: 0.994963838343
#  f1: 0.935840016424
#  time: 45.892914056777954
# solver: saga
#  max_iter: 10000
#  C: 1
#  roc auc: 0.999128763461
#  f1: 0.983827394049
#  time: 225.96953701972961

# %% [markdown]
# From the results above we can conclude that the best parameters for Logistic Regression are:
#  solver: liblinear,max_iter: 1000, C: 1. Then, we will use these parameters in our model.

# %% [markdown]
# # Validation on test data

# %%
data_scale_train = X_train[num_features]
data_scale_test = X_test[num_features]
scaler = StandardScaler()
data_scaled_train = scaler.fit_transform(data_scale_train)
data_scaled_test = scaler.transform(data_scale_test)

data_dum_train = X_train.drop(X_train[num_features], axis = 1)
data_dum_test = X_test.drop(X_test[num_features], axis = 1)
 
ohe = OneHotEncoder(categorical_features='all',sparse=True)
data_ohe_train = ohe.fit_transform(data_dum_train)
data_ohe_test = ohe.transform(data_dum_test)

X_train_sparse = hstack([data_scaled_train, data_ohe_train\
                                    ]).tocsr(copy = False) 

X_test_sparse = hstack([data_scaled_test, data_ohe_test\
                             ]).tocsr(copy = False)

# %%
from sklearn.metrics import f1_score, roc_auc_score

start = time()
model = LogisticRegression(solver='liblinear', max_iter=1000, C=1, random_state=777)
model.fit(X_train_sparse, y_train)
preds = model.predict(X_test_sparse)
score = roc_auc_score(y_test, preds)
scoref1 = f1_score(y_test, preds)
end = time()
ste = end - start
print('solver:', i, '\n', 'max_iter:', j, '\n', 'C:', k, '\n',\
                      'roc auc:', score, '\n', 'f1:', scoref1, '\n', 'time:', ste)
# Out:
# solver: saga
#  max_iter: 10000
#  C: 1
#  roc auc: 0.981687898089
#  f1: 0.981346309813
#  time: 0.5023932456970215

# %% [markdown]
# # Prediction for validation dataset

# %%
X_train = X_train.append(X_test).reset_index().drop('index', axis=1)
y_train = y_train.append(y_test)

data_scale_train = X_train[num_features]
data_scale_test = X_valid[num_features]
scaler = StandardScaler()
data_scaled_train = scaler.fit_transform(data_scale_train)
data_scaled_test = scaler.transform(data_scale_test)

data_dum_train = X_train.drop(X_train[num_features], axis = 1)
data_dum_test = X_valid.drop(X_test[num_features], axis = 1)

 
ohe = OneHotEncoder(categorical_features='all',sparse=True)
data_ohe_train = ohe.fit_transform(data_dum_train)
data_ohe_test = ohe.transform(data_dum_test)

X_train_sparse = hstack([data_scaled_train, data_ohe_train\
                                    ]).tocsr(copy = False) 

X_test_sparse = hstack([data_scaled_test, data_ohe_test\
                             ]).tocsr(copy = False)

# %%
from sklearn.metrics import f1_score, roc_auc_score
start = time()
model = LogisticRegression(solver='liblinear', max_iter=1000, C=1, random_state=777)
model.fit(X_train_sparse, y_train)
preds = model.predict(X_test_sparse)
score = roc_auc_score(y_valid, preds)
scoref1 = f1_score(y_valid, preds)
end = time()
ste = end - start
print('solver:', i, '\n', 'max_iter:', j, '\n', 'C:', k, '\n',\
                      'roc auc:', score, '\n', 'f1:', scoref1, '\n', 'time:', ste)
# Out:
# solver: saga
#  max_iter: 10000
#  C: 1
#  roc auc: 0.996768982229
#  f1: 0.996758508914
#  time: 0.527630090713501

# %% [markdown]
# We can see the the quality of the model does not change a lot on test and validation. Therefore the model can be used as classifier

# %% [markdown]
# # Summary
# Our Logistic Regression classifier was able to get a very high scores on train, test and validation datasets.
# It means that we can predict whether or not the Sales order of the enterprise can be rejected.
#
# How to improve our model:
# * Get more data about different reasons for rejection
# * try to predict thses different reasons for rejection. In other words, resolve a task of multiclass classification
# * Use different methods for deleting NaN values, not just substitute them to zeros.
# * Since we have many categorical features in our dataset, Catboost algorithm, that uses expanding mean encoding for categorical features, might be useful.
